# %%
import pandas as pd
import numpy as np
import csv

# %%
csv_path = "matrix10.csv"

# %%
df = pd.read_csv(csv_path)
df.dtypes
# Out:
#  2       int64
#  9       int64
#  4       int64
#  5       int64
#  0       int64
#          ...
#  9 .6    int64
#  5 .8    int64
#  1 .4    int64
#  5 .9    int64
#  8       int64
# Length: 77, dtype: object

# %%
with open(csv_path,"r") as csv_file:
    reader=csv.reader(csv_file)
    my_list = []
    for row in reader:
        new_row = [int(i)for i in row]
        my_list.append(new_row)

# %%
my_list
# Out:
# [[2,
#   9,
#   4,
#   5,
#   0,
#   5,
#   8,
#   0,
#   8,
#   8,
#   7,
#   7,
#   5,
#   1,
#   8,
#   6,
#   2,
#   2,
#   3,
#   1,
#   0,
#   5,
#   0,
#   7,
#   9,
#   9,
#   10,
#   7,
#   8,
#   1,
#   0,
#   8,
#   6,
#   8,
#   7,
#   3,
#   2,
#   2,
#   3,
#   10,
#   5,
#   3,
#   3,
#   4,
#   2,
#   8,
#   2,
#   0,
#   9,
#   9,
#   10,
#   7,
#   5,
#   2,
#   6,
#   8,
#   8,
#   6,
#   7,
#   10,
#   5,
#   5,
#   4,
#   9,
#   4,
#   6,
#   3,
#   2,
#   7,
#   0,
#   1,
#   2,
#   9,
#   5,
#   1,
#   5,
#   8],
#  [5,
#   6,
#   6,
#   0,
#   7,
#   6,
#   7,
#   3,
#   8,
#   4,
#   7,
#   5,
#   7,
#   7,
#   2,
#   6,
#   7,
#   3,
#   6,
#   7,
#   10,
#   9,
#   3,
#   10,
#   5,
#   9,
#   4,
#   4,
#   2,
#   10,
#   5,
#   8,
#   8,
#   1,
#   10,
#   7,
#   6,
#   7,
#   6,
#   7,
#   1,
#   8,
#   8,
#   5,
#   9,
#   9,
#   4,
#   7,
#   9,
#   9,
#   5,
#   10,
#   1,
#   4,
#   3,
#   7,
#   4,
#   9,
#   7,
#   8,
#   7,
#   6,
#   6,
#   10,
# ...
